# %%
import math
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.DataFrame({
    # 'Mes': ,
    'Mes': np.random.choice(['Ene', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dic'], 100),
    'Gastos': [math.floor(x*1000000 + 30000000) for x in np.random.rand(100).data.tolist()],
    'Ingresos': [math.floor(x*2000000 + 40000000) for x in np.random.rand(100).data.tolist()],
})

data.head(-1)
# Out:
#     Mes    Gastos  Ingresos
# 0   Sep  30922242  40533121
# 1   Ene  30385764  40411383
# 2   Ene  30723497  40320454
# 3   May  30673089  40994542
# 4   Sep  30848047  41752473
# ..  ...       ...       ...
# 94  Dic  30735331  40187962
# 95  May  30913232  40441890
# 96  Aug  30723482  41297649
# 97  Oct  30795704  40391425
# 98  Aug  30898253  41571964
#
# [99 rows x 3 columns]

# %%
sns.barplot(x='Mes', y='Gastos', data=data)
plt.title("Gastos x mes")
plt.show()

sns.violinplot(x='Mes', y='Gastos', data=data)
plt.title("Gastos x mes")
plt.show()

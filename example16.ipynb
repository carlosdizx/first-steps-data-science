# %% [markdown]
# # Funciones algebraicas

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %% [markdown]
# ## 1. Función lineal

# %%
n = 100

x1 = 0
y1 = 1

# %%
x = np.linspace(-10, 10, num=n)

# %%
def find_equation_of_line(m, x, b):
    return m * x + b

def find_slope(x2, y2):
    return (y2 - y1) / (x2 - x1)

# %% [markdown]
# Ejemplos:
# $$ y = x + 1 $$
# $$ y = 0.33X + 1 $$
# $$ y = -0.17X + 1 $$

# %%
m = round(find_slope(1, 2), 2)
b = y1 - m * x1
y = find_equation_of_line(m, x, b)


plt.figure(figsize=(15, 10))

sns.lineplot(data= y, color='skyblue', label=f"f(x) = {m}x + {b}")

m = round(find_slope(3, 2), 2)
b = y1 - m * x1
y = find_equation_of_line(m, x, b)

sns.lineplot(data= y, color='salmon', label=f"f(x) = {m}x + {b}")


m = round(find_slope(3, 0.5), 2)
b = y1 - m * x1
y = find_equation_of_line(m, x, b)

sns.lineplot(data= y, color='lightgreen', label=f"f(x) = {m}x + {b}")
# Out:
# <Axes: >

# %% [markdown]
# ## 2. Función polinómica

# %% [markdown]
# Ejemplo:
# $$ 2X^7 - X^4 + 3X^2 + 4 $$

# %%
def examplePolynomial(x):
    return 2 * x ** 7 - 4 * x ** 3 + 3 * x **2 + 4

# %%
y = examplePolynomial(x)

plt.figure(figsize=(15, 10))
sns.lineplot(data= y, color='lightgreen')
# Out:
# <Axes: >

# %% [markdown]
# # Funciones trascendentes

# %% [markdown]
# ## 1. Funciones trigonométricas
#
# Ejemplo:
#
# $$ sin(x) $$
# $$ cos(x) $$

# %%
def cos(x):
    return np.cos(x)
    
def sin(x):
    return np.sin(x)

# %%
y = cos(x)

plt.figure(figsize=(15, 10))

sns.lineplot(data= y, color='salmon', label=f"cos(x)")

y = sin(x)
sns.lineplot(data= y, color='lightgreen', label=f"sin(x)")
# Out:
# <Axes: >

# %% [markdown]
# ## 2. Función exponencial
#
# Ejemplo:
#
# $$ x^x $$
# $$ e^x $$

# %%
def exponential(x):
    return np.exp(x) + 6

def e_exponential(x):
    return np.e ** x

# %%
x = np.linspace(-5, 5, num=n)

plt.figure(figsize=(15, 10))

y = exponential(x)
sns.lineplot(data= y, color='salmon', label=f"x^x")

y = e_exponential(x)
sns.lineplot(data= y, color='green', label=f"e^x")
# Out:
# <Axes: >

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
data = pd.DataFrame({
    'Category': np.random.choice(['A', 'B', 'C'], 100),
    'Value': np.random.rand(100)
})

data.head(-1)
# Out:
#    Category     Value
# 0         C  0.818777
# 1         C  0.595913
# 2         C  0.826932
# 3         B  0.905025
# 4         A  0.062933
# ..      ...       ...
# 94        C  0.760860
# 95        B  0.130860
# 96        B  0.964870
# 97        A  0.272378
# 98        A  0.148941
#
# [99 rows x 2 columns]

# %%
sns.barplot(x='Category', y='Value', data=data )
plt.title("Graphic of Bars")
plt.show()

sns.barplot(y='Category', x='Value', data=data, orient='h')
plt.title("Graphic of Bars")
plt.show()

# %%
data_scatterplot= pd.DataFrame({
    'X': np.random.rand(100),
    'Y': np.random.rand(100),
    'Category': np.random.choice(['A', 'B', 'C'], 100)
})

data_scatterplot.head(-1)
# Out:
#            X         Y Category
# 0   0.788887  0.058276        C
# 1   0.001091  0.265094        C
# 2   0.260053  0.058627        A
# 3   0.895164  0.371282        A
# 4   0.274570  0.125550        B
# ..       ...       ...      ...
# 94  0.064819  0.778414        A
# 95  0.899426  0.376381        C
# 96  0.491484  0.599890        B
# 97  0.007654  0.037225        A
# 98  0.927182  0.271169        C
#
# [99 rows x 3 columns]

# %%
sns.scatterplot(x='X', y='Y',hue='Category' , data=data_scatterplot)
plt.grid(False)
plt.title("Graphic Scatterplot")
plt.show()

# %%
sns.histplot(data['Value'], bins=20, kde=True)
# Out:
# <Axes: xlabel='Value', ylabel='Count'>

# %%
sns.violinplot(x='Category', y='Value', data=data)
# Out:
# <Axes: xlabel='Category', ylabel='Value'>

# %%
data_matrix = np.random.rand(10, 10)
sns.heatmap(data_matrix, annot=True)
# Out:
# <Axes: >
